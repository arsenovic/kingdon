# %%
import numpy as np
from kingdon.blademap  import BladeMap
from kingdon import Algebra
from kingdon.numerical import exp 
from itertools import pairwise



pga = Algebra(2,0,1,start_index=0) 
locals().update(pga.blades)
basis_vectors= pga.blades_of_grade(1)


# coordinate operators
T  = lambda x,y: exp((x*e01 + y*e02)/2)
R  = lambda theta: exp(theta*e12/2)
RT = lambda rho,theta: R(theta)*T(rho,0)*T(1,0) 
 
angles = np.linspace(0,2*np.pi,41)[:-1]
distances = np.linspace(0,1,11)
cart_coords = np.meshgrid(distances,distances)
polar_coords = np.meshgrid(distances,angles)


polar_points = RT(*polar_coords)>>e0.dual() # 
cart_points  = T(*cart_coords)>>e0.dual() #

# %%
pga.graph(
    0x23422faf , *polar_points.flatten(),
    0x2ab22faf , *cart_points.flatten(),

   # 0x23422faf , *list(pairwise(points.flatten())),
    grid=False,lineWidth=4, 
)

# %%
O(*coords).blades
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 O(*coords).blades
#
# File ~/code/kingdon/kingdon/multivector.py:379, in MultiVector.__getattr__(self, basis_blade)
#     376 def __getattr__(self, basis_blade):
#     377     # TODO: if this first check is not true, raise hell instead?
#     378     if not re.match(r'^e[0-9a-fA-Z]*$', basis_blade):
# --> 379         raise AttributeError(f'{self.__class__.__name__} object has no attribute or basis blade {basis_blade}')
#     380     basis_blade, swaps = self.algebra._blade2canon(basis_blade)
#     381     if basis_blade not in self.algebra.canon2bin:
#
# AttributeError: MultiVector object has no attribute or basis blade blades

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 pga.graph(
# ----> 2     0x23422faf , points.flatten(),
#       3     grid=True,
#       4 )
#
# File ~/code/kingdon/kingdon/multivector.py:185, in MultiVector.flatten(self)
#     176 def flatten(self):
#     177     """
#     178     Flatten a multidimensional multivector into a list of 1D multivectors.
#     179
#    (...)    183     :return: List of flattened multivectors.
#     184     """
# --> 185     return [self[i] for i in np.ndindex(self.shape[1:])]
#
# File ~/code/kingdon/kingdon/multivector.py:356, in MultiVector.__getitem__(self, item)
#     354 values = self.values()
#     355 if isinstance(values, (tuple, list)):
# --> 356     return_values = values.__class__(value[item] for value in values)
#     357 else:
#     358     return_values = values[(slice(None), *item)]
#
# ...

# %%
points = T(pga.vector(coords))>>e0.dual()


pga.graph(
    0x23422faf , points.flatten(),
    grid=True,
)

# %%
# form product of vectors and coordinates
pga.vector([1]+[2,3])
# Out:
# 1 𝐞₀ + 2 𝐞₁ + 3 𝐞₂

# %%
pga2.blades
# Out:
# BladeDict(algebra=Algebra(p=2, q=0, r=1, signature=array([0, 1, 1])), lazy=False)
